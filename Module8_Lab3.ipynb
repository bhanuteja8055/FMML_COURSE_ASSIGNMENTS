# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanuteja8055/FMML_COURSE_ASSIGNMENTS/blob/main/Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 02:04:01--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   267MB/s    in 0.3s
#
# 2023-05-04 02:04:05 (267 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35355  cs/0412002v3  We compare two link analysis ranking methods o...    cs
# 15813  1605.06770v1  In this paper, a novel approach is proposed to...    cs
# 37875   1006.3972v1  Undirected graphical models encode in a graph ...  stat
# 1633   1703.07055v1  Language understanding is a key component in a...    cs
# 18276   0709.4015v1  This paper describes a system capable of semi-...    cs
# ...             ...                                                ...   ...
# 11104   1407.2433v3  This paper investigates methods for quantifyin...    cs
# 12136  1709.02194v1  Much combinatorial optimisation problems const...  stat
# 24422   1312.1685v1  In this paper, we present a novel Gabor wavele...    cs
# 39869  1706.07422v1  An important aspect of examining printed docum...    cs
# 11253  1506.04209v2  We propose a general algorithmic framework for...  stat
#
#                                                    title  year  \
# 35355  Ranking Pages by Topology and Popularity withi...  2004
# 15813  Automatic Construction of Discourse Corpora fo...  2016
# 37875                            Graph-Valued Regression  2010
# 1633   Investigation of Language Understanding Impact...  2017
# 18276  From Texts to Structured Documents: The Case o...  2007
# ...                                                  ...   ...
# 11104  Identifying Cover Songs Using Information-Theo...  2014
# 12136  Approximating meta-heuristics with homotopic r...  2017
# 24422  Human Face Recognition using Gabor based Kerne...  2013
# 39869  Single Classifier-based Passive System for Sou...  2017
# 11253  A Flexible and Efficient Algorithmic Framework...  2015
#
#                                                 keywords
# 35355  [adaptation, granularity, popularity, frequenc...
# 15813  [automatically, construct, discourse, translat...
# 37875  [undirected, graphical, dependency, structure,...
# 1633   [understanding, component, investigate, unders...
# 18276  [describes, automatically, information, explic...
# ...                                                  ...
# 11104  [investigates, quantifying, similarity, specif...
# 12136  [combinatorial, optimisation, constitute, poly...
# 24422  [component, integrating, transformation, recog...
# 39869  [important, examining, documents, potential, f...
# 11253  [algorithmic, framework, constrained, factoriz...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35355    [adaptation, granularity, popularity, frequenc...
# 15813    [automatically, construct, discourse, translat...
# 37875    [undirected, graphical, dependency, structure,...
# 1633     [understanding, component, investigate, unders...
# 18276    [describes, automatically, information, explic...
#                                ...
# 36048    [challenges, electronic, government, developme...
# 27375    [recognition, evaluating, establishing, furthe...
# 22419    [introduce, approximation, selection, procedur...
# 40822    [classifying, imprecise, classifiers, generate...
# 2464     [aggregation, aggregation, classification, cur...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8730 words.
# Out of those 4519 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="91c09e81-2b2f-4394-bf9d-f0f82d49d6ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91c09e81-2b2f-4394-bf9d-f0f82d49d6ce")) {                    Plotly.newPlot(                        "91c09e81-2b2f-4394-bf9d-f0f82d49d6ce",                        [{"x":["surprisingly","aggregate","frequencies","navigation","instrumental","spearmans","popularity","artificially","employing","behaviour","reasonable","nonparametric","approximation","distributions","different","adaptation","experiments","granularity","information","corresponding","construction","construct","automatic","integrate","bilingual","annotation","monolingual","automatically","retrieval","improvement","qualities","translation","discourse","collected","projected","regression","theoretical","undirected","partitioning","application","applications","optimized","structure","establishing","analyzing","graphical","estimating","properties","conditioned","dependency","partition","demonstrate","inequalities","consistency","estimates","semiparametric","minimization","component","understanding","performance","empirical","investigation","systematic","investigate","influences","conducting","robustness","reinforcement","expressing","therefore","structured","documents","developed","explicitly","sequences","guidelines","describes","conditions","recommendation","according","historical","algorithms","integrated","evaluation","relevance","consequence","algorithm","interpolated","framework","reconstruction","statistical","mechanical","interpolation","probabilistically","engineering","deterministically","treatment","observations","biological","flexibility","likelihood","components","discussed","selection","neighborhood","combination","available","classification","parameters","hierarchical","unsupervised","initialisation","illustrated","determine","classical","simulation","parametric","proposals","experimental","detection","computations","possibilities","resolution","generation","dimension","efficient","convolutional","implement","especially","performances","architecture","consumptions","efficiency","concerning","attention","resolutions","platforms","optimizations","statistics","compressed","variation","importance","optimization","dimensional","conjectured","transition","understood","recovering","denoising","rigorously","transitions","characterizing","characterize","approximate","important","predominantly","considering","dependent","influenced","discussion","approaches","geographic","influencing","techniques","particular","effective","prediction","perspective","conventional","technique","understand","modelling","comprehensive","difficult","complexity","improvements","synthetic","baselines","theoretically","estimator","expensive","significant","computational","convergence","estimation","estimators","parallelizable","requirement","penalized","elementary","contributions","consistent","situation","predictive","transformations","experiment","extensive","representation","competitions","empirically"],"y":[25,21,18,35,6,2,21,10,32,29,32,27,109,123,756,69,632,9,690,129,63,84,165,37,12,68,8,182,109,155,9,94,18,77,19,109,134,6,17,256,431,46,345,12,59,54,58,212,20,53,24,595,6,61,65,1,53,115,162,899,136,25,37,148,9,7,100,101,15,136,104,61,215,74,116,14,86,124,28,101,20,588,60,269,40,18,799,4,572,100,141,11,19,4,59,3,24,69,39,29,67,100,59,169,25,134,287,505,241,119,125,2,27,75,90,60,33,25,376,341,41,12,111,168,65,417,406,68,125,39,257,2,172,17,164,12,32,8,65,33,64,84,326,184,2,36,21,29,45,9,13,20,43,113,311,6,67,72,10,23,413,6,4,377,279,262,222,72,99,269,66,48,65,133,215,107,150,62,40,27,61,233,300,121,206,15,8,38,1,15,43,70,25,55,39,78,178,362,8,64],"type":"bar"},{"x":["surprisingly","aggregate","frequencies","navi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4519,), (4519, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypothesis</span> <span style='background-color:rgba(0, 255, 0, 0.6799999999999999);'>Generation</span> <span style=''>for</span> <span style=''>6D</span> <span style=''>Object</span> <span style=''>Pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addresses</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4170854271356783);'>estimating</span> <span style=''>the</span> <span style=''>6D</span> <span style=''>pose</span> <span style=''>of</span> <span style=''>a</span> <span style=''>known</span> <span style=''>3D</span> <span style=''>object</span> <span style=''>from</span> <span style=''>a</span> <span style=''>single</span> <span style=''>RGB</span> <span style=''>D</span> <span style=''>image</span> <span style=''>Most</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>task</span> <span style=''>in</span> <span style=''>three</span> <span style=''>steps</span> <span style=''>i)</span> <span style=''>Compute</span> <span style=''>local</span> <span style=''>features</span> <span style=''>ii)</span> <span style=''>Generate</span> <span style=''>a</span> <span style=''>pool</span> <span style=''>of</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>hypotheses</span> <span style=''>iii)</span> <span style=''>Select</span> <span style=''>and</span> <span style=''>refine</span> <span style=''>a</span> <span style=''>pose</span> <span style=''>from</span> <span style=''>the</span> <span style=''>pool</span> <span style=''>This</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style=''>second</span> <span style=''>step</span> <span style=''>While</span> <span style=''>all</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>generate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>hypotheses</span> <span style=''>pool</span> <span style=''>via</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.8014184397163121);'>reasoning</span> <span style=''>eg</span> <span style=''>RANSAC</span> <span style=''>or</span> <span style=''>Hough</span> <span style=''>voting</span> <span style=''>we</span> <span style=''>are</span> <span style=''>the</span> <span style=''>first</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.8014184397163121);'>reasoning</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>beneficial</span> <span style=''>at</span> <span style=''>this</span> <span style=''>stage</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>(CRF)</span> <span style=''>that</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>very</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>hypotheses</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>How</span> <span style=''>to</span> <span style=''>Make</span> <span style=''>Causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inferences</span> <span style=''>Using</span> <span style=''>Texts</span> <br/><br/><span style=''>New</span> <span style=''>text</span> <span style=''>as</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>offer</span> <span style=''>a</span> <span style=''>great</span> <span style=''>promise</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductively</span> <span style=''>discover</span> <span style=''>measures</span> <span style=''>that</span> <span style=''>are</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>testing</span> <span style=''>social</span> <span style=''>science</span> <span style=''>theories</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>from</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>text</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>making</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferences</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovered</span> <span style=''>measures</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>or</span> <span style=''>outcome</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>enables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>textual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interventions</span> <span style=''>and</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>ways</span> <span style=''>that</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>affect</span> <span style=''>text</span> <span style=''>based</span> <span style=''>outcomes</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>nearly</span> <span style=''>all</span> <span style=''>text</span> <span style=''>based</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferences</span> <span style=''>depend</span> <span style=''>upon</span> <span style=''>a</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>text</span> <span style=''>and</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>But</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>this</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>we</span> <span style=''>show</span> <span style=''>creates</span> <span style=''>new</span> <span style=''>ri ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Group</span> <span style=''>sparse</span> <span style=''>Matrix</span> <span style=''>Recovery</span> <br/><br/><span style=''>We</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>OSCAR</span> <span style=''>(octagonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>regression)</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovering</span> <span style=''>group</span> <span style=''>sparse</span> <span style=''>matrices</span> <span style=''>(two</span> <span style='background-color:rgba(255, 0, 0, 0.3588850174216028);'>dimensional</span> <span style=''>2D</span> <span style=''>arrays)</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compressive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>2D</span> <span style=''>version</span> <span style=''>of</span> <span style=''>OSCAR</span> <span style=''>(2OSCAR)</span> <span style='background-color:rgba(0, 255, 0, 0.36000000000000004);'>consisting</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>pair</span> <span style=''>wise</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>norm</span> <span style=''>which</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>but</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proximity</span> <span style=''>operator</span> <span style=''>of</span> <span style=''>2OSCAR</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>based</span> <span style=''>on</span> <span style=''>that</span> <span style=''>of</span> <span style=''>OSCAR</span> <span style=''>The</span> <span style=''>2OSCAR</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>thus</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>proximal</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>splitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>group</span> <span style=''>sparse</span> <span style=''>2D</span> <span style=''>array</span> <span style=''>recovery</span> <span style=''>show</span> <span style=''>that</span> <span style=''>2OSCAR</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>regularization</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>the</span> <span style=''>SpaRSA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>the</span> <span style=''>fastest</span> <span style=''>choice</span> <span style=''>while</span> <span style=''>the</span> <span style=''>PADMM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(with</span> <span style=''>debiasing)</span> <span style=''>yields</span> <span style=''>the</span> <span style=''>most</span> <span style=''>accurate</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Introduction</span> <span style=''>to</span> <span style=''>Deep</span> <span style=''>Visual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>so</span> <span style=''>much</span> <span style=''>so</span> <span style=''>that</span> <span style=''>almost</span> <span style=''>every</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Artificial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intelligence</span> <span style=''>problem</span> <span style=''>or</span> <span style=''>at</span> <span style=''>least</span> <span style=''>a</span> <span style=''>portion</span> <span style=''>thereof</span> <span style=''>has</span> <span style=''>been</span> <span style=''>somehow</span> <span style=''>recast</span> <span style=''>as</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>appeal</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>but</span> <span style=''>this</span> <span style=''>appeal</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenged</span> <span style=''>by</span> <span style=''>what</span> <span style=''>some</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explainability</span> <span style=''>or</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>the</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style=''>debuggability</span> <span style=''>if</span> <span style=''>the</span> <span style=''>outcomes</span> <span style=''>of</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexpected</span> <span style=''>results</span> <span style=''>(eg</span> <span style=''>less</span> <span style=''>than</span> <span style=''>expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>classifier)</span> <span style=''>then</span> <span style=''>there</span> <span style=''>is</span> <span style=''>little</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>the</span> <span style=''>way</span> <span style=''>of</span> <span style=''>theories</span> <span style=''>or</span> <span style=''>tools</span> <span style=''>to</span> <span style=''>help</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>causes</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09763948497854077)
# 	knowledge (0.1223175965665236)
# 	representation (0.12947067238912732)
# 	architecture (0.0919170243204578)
# 	segmentation (0.06938483547925609)
# 	detection (0.12195994277539342)
# 	information (0.24678111587982832)
# 	different (0.2703862660944206)
# 	recognition (0.13090128755364808)
# 	convolutional (0.1452074391988555)
#
# Some Statistics words are:
# 	distributions (0.11826347305389222)
# 	variables (0.14520958083832336)
# 	statistical (0.1437125748502994)
# 	estimation (0.17714570858283432)
# 	theoretical (0.15469061876247506)
# 	distribution (0.18463073852295409)
# 	algorithm (0.3972055888223553)
# 	inference (0.1936127744510978)
# 	dimensional (0.19461077844311378)
# 	regression (0.1751497005988024)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="87e16efe-af48-446c-bfdd-d778c9a07f56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87e16efe-af48-446c-bfdd-d778c9a07f56")) {                    Plotly.newPlot(                        "87e16efe-af48-446c-bfdd-d778c9a07f56",                        [{"x":["surprisingly","aggregate","frequencies","navigation","instrumental","spearmans","popularity","artificially","employing","behaviour","reasonable","nonparametric","approximation","distributions","different","adaptation","experiments","granularity","information","corresponding","construction","construct","automatic","integrate","bilingual","annotation","monolingual","automatically","retrieval","improvement","qualities","translation","discourse","collected","projected","regression","theoretical","undirected","partitioning","application","applications","optimized","structure","establishing","analyzing","graphical","estimating","properties","conditioned","dependency","partition","demonstrate","inequalities","consistency","estimates","semiparametric","minimization","component","understanding","performance","empirical","investigation","systematic","investigate","influences","conducting","robustness","reinforcement","expressing","therefore","structured","documents","developed","explicitly","sequences","guidelines","describes","conditions","recommendation","according","historical","algorithms","integrated","evaluation","relevance","consequence","algorithm","interpolated","framework","reconstruction","statistical","mechanical","interpolation","probabilistically","engineering","deterministically","treatment","observations","biological","flexibility","likelihood","components","discussed","selection","neighborhood","combination","available","classification","parameters","hierarchical","unsupervised","initialisation","illustrated","determine","classical","simulation","parametric","proposals","experimental","detection","computations","possibilities","resolution","generation","dimension","efficient","convolutional","implement","especially","performances","architecture","consumptions","efficiency","concerning","attention","resolutions","platforms","optimizations","statistics","compressed","variation","importance","optimization","dimensional","conjectured","transition","understood","recovering","denoising","rigorously","transitions","characterizing","characterize","approximate","important","predominantly","considering","dependent","influenced","discussion","approaches","geographic","influencing","techniques","particular","effective","prediction","perspective","conventional","technique","understand","modelling","comprehensive","difficult","complexity","improvements","synthetic","baselines","theoretically","estimator","expensive","significant","computational","convergence","estimation","estimators","parallelizable","requirement","penalized","elementary","contributions","consistent","situation","predictive","transformations","experiment","extensive","representation","competitions","empirically","outperformed","relational","automation","predefining","heuristics","predefined","analytics","solutions","appropriate","knowledge","introduce","particularly","hierarchy","plausible","fundamental","characterized","effectively","organization","autoencoder","associated","unlabeled","meaningful","augmented","autoencoders","variations","hierarchies","structural","bidirectional","arbitrary","structures","generative","perceptual","adversarial","principles","relationships","synthesis","recursive","adjacency","supervision","complexities","resulting","traditional","footprint","contributing","reduction","reductions","algorithmic","illustrate","minimizing","clustering","improving","quadratic","projections","subsequent","appro ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	agglomeration
# 	periodicity
# 	admitting
# 	integrations
# 	unfavorable
# 	criticism
# 	forecaster
# 	multilabel
# 	compounds
# 	integrands
# 	combinatorially
# 	precautions
# 	diagonalise
# 	circularity
# 	nesterovs
# 	defensive
# 	unsettled
# 	entrywise
# 	fingerprinting
# 	logarithmically
# Some words which never appear in Statistics papers:
# 	discourse
# 	endeavour
# 	attracting
# 	solomonoffs
# 	synonymous
# 	extractions
# 	redistribution
# 	dempsters
# 	smarandache
# 	formalisms
# 	nonmonotonic
# 	introspection
# 	entailment
# 	propositional
# 	hourglass
# 	reflections
# 	incentive
# 	pronunciations
# 	acceptable
# 	subnetworks

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078912528095077e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
